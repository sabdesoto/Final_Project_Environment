# %% [markdown]
# ## Loading Data

# %% [markdown]
# ## Statistis for my data

# %%
# import libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#stats library

import statsmodels.api as sm
import scipy

#T-test is imported to complete the statistical analysis

from scipy.stats import ttest_ind

from scipy import stats

#The function below is used to show the plots within the notebook

# %matplotlib inline

# %% [markdown]
# ## Loading Data using Pandas

# %%
data=pd.read_csv('/Users/Jhanelle/Desktop/CO2_behav.dat', delimiter=' ')

# %%
data
# Out:
#              date            plate     time  strain  frame   ID  persistance  \
# 0        20120731  20120731_120745   15.039      N2      0    1        234.9
# 1        20120731  20120731_120745   15.080      N2      1    1        234.9
# 2        20120731  20120731_120745   15.125      N2      2    1        234.9
# 3        20120731  20120731_120745   15.160      N2      3    1        234.9
# 4        20120731  20120731_120745   15.198      N2      4    1        234.9
# 5        20120731  20120731_120745   15.240      N2      5    1        234.9
# 6        20120731  20120731_120745   15.280      N2      6    1        234.9
# 7        20120731  20120731_120745   15.321      N2      7    1        234.9
# 8        20120731  20120731_120745   15.361      N2      8    1        234.9
# 9        20120731  20120731_120745   15.398      N2      9    1        234.9
# 10       20120731  20120731_120745   15.441      N2     10    1        234.9
# 11       20120731  20120731_120745   15.481      N2     11    1        234.9
# 12       20120731  20120731_120745   15.522      N2     12    1        234.9
# 13       20120731  20120731_120745   15.563      N2     13    1        234.9
# 14       20120731  20120731_120745   15.600      N2     14    1        234.9
# 15       20120731  20120731_120745   15.641      N2     15    1        234.9
# 16       20120731  20120731_120745   15.682      N2     16    1        234.9
# 17       20120731  20120731_120745   15.723      N2     17    1        234.9
# 18       20120731  20120731_120745   15.763      N2     18    1        234.9
# 19       20120731  20120731_120745   15.801      N2     19    1        234.9
# 20       20120731  20120731_120745   15.841      N2     20    1        234.9
# 21       20120731  20120731_120745   15.882      N2     21    1        234.9
# 22       20120731  20120731_120745   15.922      N2     22    1        234.9
# 23       20120731  20120731_120745   15.963      N2     23    1        234.9
# 24       20120731  20120731_120745   16.002      N2     24    1        234.9
# 25       20120731  20120731_120745   16.041      N2     25    1        234.9
# 26       20120731  20120731_120745   16.083      N2     26    1        234.9
# 27       20120731  20120731_120745   16.124      N2     27    1        234.9
# 28       20120731  20120731_120745   16.165      N2     28    1        234.9
# 29       20120731  20120731_120745   16.204      N2     29    1        234.9
# ...           ...              ...      ...     ...    ...  ...          ...
# 1150355  20120807  20120807_160710  241.955  MX1027   5618  468         27.6
# 1150356  20120807  20120807_160710  241.996  MX1027   5619  468         27.6
# 1150357  20120807  20120807_160710  242.036  MX1027   5620  468         27.6
# 1150358  20120807  20120807_160710  242.076  MX1027   5621  468         27.6
# 1150359  20120807  20120807_160710  242.116  MX1027   5622  468         27.6
# 1150360  20120807  20120807_160710  242.157  MX1027   5623  468         27.6
# 1150361  20120807  20120807_160710  242.197  MX1027   5624  468         27.6
# 1150362  20120807  20120807_160710  242.238  MX1027   5625  468         27.6
# 1150363  20120807  20120807_160710  242.278  MX1027   5626  468         27.6
# 1150364  20120807  20120807_160710  242.317  MX1027   5627  468         27.6
# 1150365  20120807  20120807_160710  242.357  MX1027   5628  468         27.6
# 1150366  20120807  20120807_160710  242.398  MX1027   5629  468         27.6
# 1150367  20120807  20120807_160710  242.438  MX1027   5630  468         27.6
# 1150368  20120807  20120807_160710  242.479  MX1027   5631  468         27.6
# 1150369  20120807  20120807_160710  242.518  MX1027   5632  468         27.6
# 1150370  20120807  20120807_160710  242.556  MX1027   5633  468         27.6
# 1150371  20120807  20120807_160710  242.599  MX1027   5634  468         27.6
# 1150372  20120807  20120807_160710  242.639  MX1027   5635  468         27.6
# 1150373  20120807  20120807_160710  242.679  MX1027   5636  468         27.6
# 1150374  20120807  20120807_160710  242.719  MX1027   5637  468         27.6
# 1150375  20120807  20120807_160710  242.756  MX1027   5638  468         27.6
# 1150376  20120807  20120807_160710  242.799  MX1027   5639  468         27.6
# 1150377  20120807  20120807_160710  242.839  MX1027   5640  468         27.6
# 1150378  20120807  20120807_160710  242.880  MX1027   5641  468         27.6
# 1150379  20120807  20120807_160710  242.919  MX1027   5642  468         27.6
# 1150380  20120807  20120807_160710  242.959  MX1027   5643  468         27.6
# 1150381  20120807  20120807_160710  242.999  MX1027   5644  468         27.6
# 1150382  20120807  20120807_160710  243.040  MX1027   5645  468         27.6
# 1150383  20120807  20120807_160710  243.081  MX1027   5646  468         27.6
# 1150384  20120807  20120807_160710  243.120  MX1027   5647  468         27.6
#
#              area   speed  angularspeed   ...    bias  pathlen  curve  dir  \
# 0        0.102789     NaN           NaN   ...       1    0.000   21.0    0
# 1        0.101331     NaN           NaN   ...       1    0.002   19.5    0
# 2        0.099873     NaN           NaN   ...       1    0.007   20.0    0
# 3        0.100602     NaN           NaN   ...       1    0.008   22.3    0
# 4        0.102060     NaN           NaN   ...       1    0.011   23.7    0
# 5        0.102789     NaN           NaN   ...       1    0.017   23.0    0
# 6        0.102789     NaN           NaN   ...       1    0.019   22.5    0
# 7        0.102789  0.0698           1.2   ...       1    0.024   21.8    0
# 8        0.101331  0.0668           1.3   ...       1    0.027   22.3    0
# 9        0.101331  0.0720           1.6   ...       1    0.027   22.9    0
# 10       0.102060  0.0783           1.8   ...       1    0.030   16.9    0
# 11       0.102789  0.0793           2.0   ...       1    0.031   19.6    0
# 12       0.103518  0.0799           2.0   ...       1    0.034   25.1    0
# 13       0.100602  0.0767           1.9   ...       1    0.037   17.7    0
# 14       0.099144  0.0799           1.9   ...       1    0.039   18.8    0
# 15       0.099144  0.0896           1.8   ...       1    0.044   18.9    0
# 16       0.099144  0.0911           1.7   ...       1    0.050   19.4    0
# 17       0.098415  0.0937           1.7   ...       1    0.056   25.9    0
# 18       0.099873  0.0919           1.7   ...       1    0.060   22.7    0
# 19       0.099144  0.0881           1.7   ...       1    0.061   22.5    0
# 20       0.098415  0.0910           1.6   ...       1    0.066   25.8    0
# 21       0.104247  0.0869           1.3   ...       1    0.072   23.2    0
# 22       0.102060  0.0814           1.1   ...       1    0.075   24.2    0
# 23       0.101331  0.0748           0.9   ...       1    0.078   24.2    0
# 24       0.102789  0.0714           0.9   ...       1    0.080   22.4    0
# 25       0.101331  0.0728           0.9   ...       1    0.080   23.6    0
# 26       0.102060  0.0716           0.7   ...       1    0.084   23.3    0
# 27       0.102060  0.0667           0.7   ...       1    0.086   23.4    0
# 28       0.102060  0.0641           0.7   ...       1    0.089   23.5    0
# 29       0.099873  0.0625           0.7   ...       1    0.091   21.9    0
# ...           ...     ...           ...   ...     ...      ...    ...  ...
# 1150355  0.066339  0.1739           6.8   ...       1    2.965   23.1    0
# 1150356  0.067068  0.1737           7.2   ...       1    2.975   22.8    0
# 1150357  0.067068  0.1741           7.3   ...       1    2.986   23.1    0
# 1150358  0.064881  0.1720           7.5   ...       1    2.991   20.8    0
# 1150359  0.065610  0.1718           7.5   ...       1    2.997   20.4    0
# 1150360  0.067068  0.1748           7.8   ...       1    3.005   21.1    0
# 1150361  0.067797  0.1812           8.2   ...       1    3.012   21.0    0
# 1150362  0.067068  0.1765           8.0   ...       1    3.019   21.7    0
# 1150363  0.067797  0.1719           7.8   ...       1    3.025   22.1    0
# 1150364  0.067797  0.1726           8.2   ...       1    3.032   22.6    0
# 1150365  0.067797  0.1697           8.2   ...       1    3.039   21.9    0
# 1150366  0.064881  0.1710           8.5   ...       1    3.047   22.7    0
# 1150367  0.064152  0.1702           8.7   ...       1    3.054   20.9    0
# 1150368  0.064881  0.1674           8.2   ...       1    3.060   21.6    0
# 1150369  0.067797  0.1709           7.8   ...       1    3.068   20.3    0
# 1150370  0.066339  0.1659           7.3   ...       1    3.075   23.4    0
# 1150371  0.067797  0.1614           7.0   ...       1    3.078   22.2    0
# 1150372  0.067797  0.1574           6.7   ...       1    3.087   22.2    0
# 1150373  0.069255  0.1521           6.2   ...       1    3.094   19.2    0
# 1150374  0.067797  0.1496           6.1   ...       1    3.099   22.2    0
# 1150375  0.069255  0.1385           5.9   ...       1    3.108   21.1    0
# 1150376  0.068526  0.1313           5.6   ...       1    3.112   21.3    0
# 1150377  0.067797     NaN           NaN   ...       1    3.117   20.7    0
# 1150378  0.067797     NaN           NaN   ...       1    3.123   21.0    0
# 1150379  0.067797     NaN           NaN   ...       1    3.127   20.7    0
# 1150380  0.067068     NaN           NaN   ...       1    3.133   21.3    0
# 1150381  0.067068     NaN           NaN   ...       0    3.133   21.3    0
# 1150382  0.066339     NaN           NaN   ...       0    3.133   21.2    0
# 1150383  0.064152     NaN           NaN   ...       0    3.133   21.3    0
# 1150384  0.064152     NaN           NaN   ...       0    3.133   21.2    0
#
#            loc_x    loc_y   vel_x   vel_y  orient    crab
# 0        13.3322  36.2338     NaN     NaN    34.2     NaN
# 1        13.3333  36.2354     NaN     NaN    34.3     NaN
# 2        13.3378  36.2375     NaN     NaN    34.3     NaN
# 3        13.3386  36.2387     NaN     NaN    34.3     NaN
# 4        13.3411  36.2405     NaN     NaN    34.3     NaN
# 5        13.3460  36.2427     NaN     NaN    34.3     NaN
# 6        13.3474  36.2450     NaN     NaN    34.4     NaN
# 7        13.3514  36.2476  0.0589  0.0374    34.5  0.0026
# 8        13.3537  36.2490  0.0551  0.0378    34.6  0.0002
# 9        13.3531  36.2493  0.0592  0.0408    34.6  0.0000
# 10       13.3561  36.2504  0.0648  0.0440    34.7  0.0007
# 11       13.3567  36.2507  0.0640  0.0467    34.7  0.0019
# 12       13.3590  36.2522  0.0661  0.0449    34.8  0.0008
# 13       13.3624  36.2534  0.0635  0.0430    34.8  0.0009
# 14       13.3628  36.2548  0.0657  0.0456    34.9  0.0002
# 15       13.3671  36.2582  0.0746  0.0496    35.1  0.0023
# 16       13.3721  36.2612  0.0746  0.0524    35.2  0.0002
# 17       13.3763  36.2653  0.0767  0.0537    35.3  0.0005
# 18       13.3798  36.2667  0.0757  0.0521    35.4  0.0013
# 19       13.3814  36.2676  0.0716  0.0514    35.4  0.0004
# 20       13.3848  36.2709  0.0748  0.0519    35.5  0.0012
# 21       13.3900  36.2734  0.0715  0.0494    35.5  0.0013
# 22       13.3922  36.2760  0.0663  0.0473    35.5  0.0000
# 23       13.3945  36.2774  0.0620  0.0418    35.6  0.0021
# 24       13.3963  36.2778  0.0586  0.0407    35.6  0.0010
# 25       13.3964  36.2784  0.0596  0.0417    35.6  0.0008
# 26       13.3998  36.2801  0.0600  0.0392    35.7  0.0031
# 27       13.4015  36.2817  0.0549  0.0379    35.7  0.0012
# 28       13.4036  36.2840  0.0537  0.0349    35.7  0.0030
# 29       13.4059  36.2849  0.0525  0.0338    35.7  0.0032
# ...          ...      ...     ...     ...     ...     ...
# 1150355  37.1433  47.0677  0.1226  0.1232  -133.1  0.0054
# 1150356  37.1504  47.0750  0.1226  0.1230  -132.5  0.0072
# 1150357  37.1578  47.0831  0.1228  0.1234  -132.1  0.0084
# 1150358  37.1613  47.0862  0.1212  0.1220  -131.9  0.0086
# 1150359  37.1653  47.0903  0.1209  0.1221  -131.6  0.0092
# 1150360  37.1707  47.0963  0.1226  0.1246  -131.5  0.0093
# 1150361  37.1761  47.1010  0.1277  0.1285  -131.3  0.0112
# 1150362  37.1811  47.1063  0.1240  0.1257  -130.9  0.0114
# 1150363  37.1852  47.1105  0.1216  0.1215  -130.6  0.0132
# 1150364  37.1905  47.1157  0.1221  0.1220  -130.1  0.0147
# 1150365  37.1953  47.1208  0.1201  0.1198  -129.8  0.0156
# 1150366  37.2005  47.1260  0.1213  0.1204  -129.4  0.0173
# 1150367  37.2059  47.1305  0.1194  0.1212  -129.1  0.0164
# 1150368  37.2096  47.1350  0.1168  0.1199  -128.7  0.0161
# 1150369  37.2157  47.1409  0.1187  0.1229  -128.4  0.0168
# 1150370  37.2210  47.1460  0.1148  0.1199  -127.9  0.0168
# 1150371  37.2233  47.1481  0.1118  0.1164  -127.7  0.0174
# 1150372  37.2291  47.1539  0.1085  0.1140  -127.3  0.0172
# 1150373  37.2339  47.1598  0.1033  0.1116  -127.0  0.0152
# 1150374  37.2368  47.1633  0.1014  0.1100  -126.9  0.0149
# 1150375  37.2427  47.1699  0.0935  0.1021  -126.9  0.0135
# 1150376  37.2457  47.1736  0.0876  0.0977  -126.7  0.0119
# 1150377  37.2493  47.1769     NaN     NaN  -126.4     NaN
# 1150378  37.2531  47.1811     NaN     NaN  -126.2     NaN
# 1150379  37.2554  47.1842     NaN     NaN  -126.1     NaN
# 1150380  37.2591  47.1887     NaN     NaN  -125.8     NaN
# 1150381  37.2601  47.1896     NaN     NaN  -125.6     NaN
# 1150382  37.2629  47.1929     NaN     NaN  -125.3     NaN
# 1150383  37.2669  47.1975     NaN     NaN  -125.1     NaN
# 1150384  37.2706  47.2021     NaN     NaN  -124.7     NaN
#
# [1150385 rows x 29 columns]

# %%
# Commans used to check the title names in each column
data.dtypes
# Out:
# date              int64
# plate            object
# time            float64
# strain           object
# frame             int64
# ID                int64
# persistance     float64
# area            float64
# speed           float64
# angularspeed    float64
# length          float64
# rellength       float64
# width           float64
# relwidth        float64
# aspect          float64
# relaspect       float64
# midline         float64
# morphwidth      float64
# kink            float64
# bias            float64
# pathlen         float64
# curve           float64
# dir             float64
# loc_x           float64
# loc_y           float64
# vel_x           float64
# vel_y           float64
# orient          float64
# crab            float64
# dtype: object

# %% [markdown]
# ### Hypothesis  and Questions
#
# ..........

# %% [markdown]
# ## Type of Statistics to perform on the data
#
#
#
# a) Liner Regression
# Variables considered for this statistical method are area and speed
#
# b) Two sampled T-test:
# Variables considered for this statistical method are strain and speed
#
#
#
# #### General Code used to calculate the two sampled t-test
#
# -> rvs1=stats.norm.rvs(loc=mean1, scale=variance, size= n)
#
# -> rvs2=stats.norm.rvs(loc=mean2, scale=variance2, size= n)
#
# --> stats.ttest_ind(rvs1,rvs2, equal_var=False)

# %%
# Here we extract only two columns from the data as these are the main variables for the statistcal analysis

strain_df=data[['strain','speed']]
strain_df.head()
# Out:
#   strain  speed
# 0     N2    NaN
# 1     N2    NaN
# 2     N2    NaN
# 3     N2    NaN
# 4     N2    NaN

# %%
# Eliminate NaN from the dataset 

strain_df=strain_df.dropna()
strain_df.head()
# Out:
#    strain   speed
# 7      N2  0.0698
# 8      N2  0.0668
# 9      N2  0.0720
# 10     N2  0.0783
# 11     N2  0.0793

# %%
#Resample the data to group by strain

strain_resampled=strain_df.groupby('strain')
strain_resampled.head()
# Out:
#         strain   speed
# 7           N2  0.0698
# 8           N2  0.0668
# 9           N2  0.0720
# 10          N2  0.0783
# 11          N2  0.0793
# 102025  MX1027  0.1134
# 102026  MX1027  0.0971
# 102027  MX1027  0.0919
# 102028  MX1027  0.0946
# 102029  MX1027  0.0982
# 217575  CHE-10  0.0947
# 217576  CHE-10  0.0910
# 217577  CHE-10  0.0882
# 217578  CHE-10  0.0872
# 217579  CHE-10  0.0846
# 864308   CHE10  0.1293
# 864309   CHE10  0.1283
# 864310   CHE10  0.1258
# 864311   CHE10  0.1276
# 864312   CHE10  0.1229

# %%
CHE10_strain=strain_df.groupby('strain').get_group('CHE10')
CHE10_strain.head()
# Out:
#        strain   speed
# 864308  CHE10  0.1293
# 864309  CHE10  0.1283
# 864310  CHE10  0.1258
# 864311  CHE10  0.1276
# 864312  CHE10  0.1229

# %%
len(CHE10_strain)
# Out:
# 155113

# %%
MX1027_type=strain_df.groupby('strain').get_group('MX1027')
MX1027_type.head()
# Out:
#         strain   speed
# 102025  MX1027  0.1134
# 102026  MX1027  0.0971
# 102027  MX1027  0.0919
# 102028  MX1027  0.0946
# 102029  MX1027  0.0982

# %%
len(MX1027_type)
# Out:
# 244428

# %%
strain_resampled.mean()
# Out:
#            speed
# strain
# CHE-10  0.054600
# CHE10   0.066482
# MX1027  0.091991
# N2      0.103593

# %%
# Variance function defined using a loop 

def variance(name):
    var=(name.std())**1/2
    return (var)

# %%
#Print variance for wild_type

variance(CHE10_strain)
# Out:
# speed    0.030493
# dtype: float64

# %%
# #Print variance for mutant_strain

variance(MX1027_type)
# Out:
# speed    0.034402
# dtype: float64

# %% [markdown]
# ##### Here we substitute the necessary values calculate to put in the general equation for t-test

# %% [markdown]
# ## Linear Regression

# %%
# This is used to only get 2 columns

rate_of_speed=data[['time','speed']]
rate_of_speed
# Out:
#             time   speed
# 0         15.039     NaN
# 1         15.080     NaN
# 2         15.125     NaN
# 3         15.160     NaN
# 4         15.198     NaN
# 5         15.240     NaN
# 6         15.280     NaN
# 7         15.321  0.0698
# 8         15.361  0.0668
# 9         15.398  0.0720
# 10        15.441  0.0783
# 11        15.481  0.0793
# 12        15.522  0.0799
# 13        15.563  0.0767
# 14        15.600  0.0799
# 15        15.641  0.0896
# 16        15.682  0.0911
# 17        15.723  0.0937
# 18        15.763  0.0919
# 19        15.801  0.0881
# 20        15.841  0.0910
# 21        15.882  0.0869
# 22        15.922  0.0814
# 23        15.963  0.0748
# 24        16.002  0.0714
# 25        16.041  0.0728
# 26        16.083  0.0716
# 27        16.124  0.0667
# 28        16.165  0.0641
# 29        16.204  0.0625
# ...          ...     ...
# 1150355  241.955  0.1739
# 1150356  241.996  0.1737
# 1150357  242.036  0.1741
# 1150358  242.076  0.1720
# 1150359  242.116  0.1718
# 1150360  242.157  0.1748
# 1150361  242.197  0.1812
# 1150362  242.238  0.1765
# 1150363  242.278  0.1719
# 1150364  242.317  0.1726
# 1150365  242.357  0.1697
# 1150366  242.398  0.1710
# 1150367  242.438  0.1702
# 1150368  242.479  0.1674
# 1150369  242.518  0.1709
# 1150370  242.556  0.1659
# 1150371  242.599  0.1614
# 1150372  242.639  0.1574
# 1150373  242.679  0.1521
# 1150374  242.719  0.1496
# 1150375  242.756  0.1385
# 1150376  242.799  0.1313
# 1150377  242.839     NaN
# 1150378  242.880     NaN
# 1150379  242.919     NaN
# 1150380  242.959     NaN
# 1150381  242.999     NaN
# 1150382  243.040     NaN
# 1150383  243.081     NaN
# 1150384  243.120     NaN
#
# [1150385 rows x 2 columns]

# %%
# this gives the mean for every 10secs of the data

rate_of_speed.index= pd.to_datetime(rate_of_speed.index, unit='s')
rate_of_speed.head(n=20)
# Out:
#                        time   speed
# 1970-01-01 00:00:00  15.039     NaN
# 1970-01-01 00:00:01  15.080     NaN
# 1970-01-01 00:00:02  15.125     NaN
# 1970-01-01 00:00:03  15.160     NaN
# 1970-01-01 00:00:04  15.198     NaN
# 1970-01-01 00:00:05  15.240     NaN
# 1970-01-01 00:00:06  15.280     NaN
# 1970-01-01 00:00:07  15.321  0.0698
# 1970-01-01 00:00:08  15.361  0.0668
# 1970-01-01 00:00:09  15.398  0.0720
# 1970-01-01 00:00:10  15.441  0.0783
# 1970-01-01 00:00:11  15.481  0.0793
# 1970-01-01 00:00:12  15.522  0.0799
# 1970-01-01 00:00:13  15.563  0.0767
# 1970-01-01 00:00:14  15.600  0.0799
# 1970-01-01 00:00:15  15.641  0.0896
# 1970-01-01 00:00:16  15.682  0.0911
# 1970-01-01 00:00:17  15.723  0.0937
# 1970-01-01 00:00:18  15.763  0.0919
# 1970-01-01 00:00:19  15.801  0.0881

# %%
#This is used to re-group some of the data

rate_of_speed_resampled=rate_of_speed.groupby('time').resample('10s', how='mean')

# %%
# This is used to print the data set
rate_of_speed_resampled.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-174f0eb76a68> in <module>()
#       1 # This is used to print the data set
# ----> 2 rate_of_speed_resampled.head()
#
# NameError: name 'rate_of_speed_resampled' is not defined

# %%
#create linear model- ols- ordinary least squares
#stats models have formula calles formula

lm= sm.formula.ols(formula='speed ~ time', data= rate_of_speed_resampled).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-58d92135b461> in <module>()
#       2 #stats models have formula calles formula
#       3
# ----> 4 lm= sm.formula.ols(formula='speed ~ time', data= rate_of_speed_resampled).fit()
#
# NameError: name 'rate_of_speed_resampled' is not defined

# %%
# This gives the beta values, the gradient is the time value

lm.params

# %%
# to use the predict function we make a data frame, therefore below we have data frame that is used to make dataframe

x_new=pd.DataFrame({'time': range(1,700)})

# %%
list(range(1,10))

# %%
x_new.head()

# %%
# create predict function to calculate linear model

y_preds=lm.predict(x_new)
y_preds[1:10]

# %%
#now we want to plot the data, therefore
speed_resampled.plot(kind='scatter', x='time', y="speed")

plt.xlim(0,700)
plt.ylim(0, 0.3)

plt.plot(x_new, y_preds, c='red', linewidth=3)

# %%
# way to get information

# This also shows that is only a 18.6% of variance in the data

print(lm.summary())

# %%
speed_resampled.hist(column='speed', bins=50)

# This is used to show the data, we can see that the data is not normal hence a linear regression is not the most suitable
plt.show()

# %%
#This is subsetting thee data
# the or is the straight bar symbol
beg_end = rate_of_speed_resampled[(rate_of_speed_resampled.time==10)|(rate_of_speed_resampled.time==590)]

# %%
beg_end.head()

# %%
# this shows the difference in the mean at both the beginning and end 
beg_end.boxplot(by='time', column='speed')
plt.show()

# %%
# the distribution for the beginning and the end

beg_end.hist(by= 'time', column='speed', bins= 25)
plt.show()

# %%
beg = beg_end.speed[beg_end.time==10]
end= beg_end.speed[beg_end.time==590]

# %%
#The p value is small so we reject the null hypothesis

scipy.stats.mstats.kruskalwallis(beg, end)
